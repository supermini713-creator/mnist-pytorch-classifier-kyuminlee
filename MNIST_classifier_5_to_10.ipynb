# %%
# 데이터 준비, 모델 준비, 손실함수, 옵티마이저 정의
import torch
from torch import nn
import torchvision
from torchvision import datasets, transforms
transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,), (0.5,))])
trainset = datasets.MNIST('-/.pytorch/MNIST_data/',download=True, train=True, transform=transform)
testset=datasets.MNIST('-/.pytorch/MNIST_data/',download=True, train=False, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
testloader = torch.utils.data.DataLoader(testset,batch_size=64, shuffle=True)
# data ready
class Classifier(nn.Module):
	def __init__(self):
		super().__init__()
		self.fc1 = nn.Linear(784, 128)
		self.fc2 = nn.Linear(128, 64)
		self.fc3 = nn.Linear(64, 10)
	def forward(self, x):
		x=x.view(x.shape[0], -1)
		x=torch.relu(self.fc1(x))
		x=torch.relu(self.fc2(x))
		x=self.fc3(x)
		return x
model = Classifier()
#model ready
print(model)
from torch import optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)
# optimizer definition compelete
epochs = 5
for e in range(epochs):
	running_loss=0
	for images, labels in trainloader:
		output = model(images)
		loss = criterion(output, labels)
		optimizer.zero_grad()
		loss.backward()
		optimizer.step()
		running_loss += loss.item()
	else:
		print(f"Epoch {e+1} - Training loss:{running_loss/len(trainloader)}")
#evaluation1 !!!!
model.eval()
correct_count, all_count = 0, 0
with torch.no_grad():
	for images, labels in testloader:
		output = model(images)
		_, predicted = torch.max(output.data,1)
		all_count += labels.size(0)
		correct_count += (predicted == labels).sum().item()
accuracy = 100 * correct_count / all_count
print(f"accuracy: {accuracy:.2f}%")
# extra 5 more epoches
model.train()
additional_epochs = 5
for e in range(additional_epochs):
	running_loss = 0
	for images, labels in trainloader:
		output = model(images)
		loss = criterion(output, labels)
		optimizer.zero_grad()
		loss.backward()
		optimizer.step()
		running_loss += loss.item()
	else:
		print(f"Epoch {e+1+epochs} - Training loss: {running_loss/len(trainloader)}")
# training over, final evaluation start
model.eval()
correct_count, all_count = 0,0
with torch.no_grad():
    for images, labels in testloader:
    	output = model(images)
    	_, predicted = torch.max(output.data, 1)
    	all_count += labels.size(0)
    	correct_count += (predicted == labels).sum().item()
accuracy = 100 * correct_count / all_count
print(f"Final Accuracy: {accuracy:.2f}%")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 9.91M/9.91M [00:14<00:00, 678kB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 28.9k/28.9k [00:00<00:00, 71.4kB/s]
# 100%|███████████████████████████████████████████████████████████████████████████████████████████| 1.65M/1.65M [00:04<00:00, 384kB/s]
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 4.54k/4.54k [00:00<00:00, 2.58MB/s]
# Classifier(
#   (fc1): Linear(in_features=784, out_features=128, bias=True)
#   (fc2): Linear(in_features=128, out_features=64, bias=True)
#   (fc3): Linear(in_features=64, out_features=10, bias=True)
# )
# Epoch 1 - Training loss:0.3433218091678645
# Epoch 2 - Training loss:0.17196330087168066
# Epoch 3 - Training loss:0.13924550735054098
# Epoch 4 - Training loss:0.12289594909869261
# Epoch 5 - Training loss:0.1105559593352523
# accuracy: 96.21%
# Epoch 6 - Training loss: 0.104354398581249
# Epoch 7 - Training loss: 0.09990336129001018
# Epoch 8 - Training loss: 0.09403038002661805
# Epoch 9 - Training loss: 0.08773619690905017
# Epoch 10 - Training loss: 0.08183895838933426
# Final Accuracy: 96.06%
